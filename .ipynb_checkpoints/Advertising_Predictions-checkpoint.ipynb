# %% [markdown]
# # Predicting Marketing Efforts: SEO and Brand Advertising
#
# Let's look at predicting the average Brand Advertising Efforts and Search Engine Optimization Efforts
#
# This helps us make more accurate decisions in BSG and identify if we'll hit the shareholder expectations for the period.

# %%
#let's grab a few packages for stats
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Let's set some variables that we'll change each round
#Change this year to the year being predicted (i.e. if you're predicting year 16, enter '16')
predictionYear = 16 

#Load the dataset from our bsg_prices_actual - Sheet1.csv
df = pd.read_csv('bsg_marketing_actual - Sheet1.csv')
df
# Out:
#    ID  YEAR  NA_SEO  NA_ADVERTISING  NA_RETAIL_SUPPORT  EU_SEO  \
# 0   0    10    5000           10000               4000    4500
# 1   1    11    5400           13150               4400    5950
# 2   2    12    7250           16650               4675    7325
# 3   3    13    8125           20600               4450    9550
# 4   4    14    7825           18750               3575    7600
# 5   5    15    9200           21000               3250    9900
#
#    EU_ADVERTISING  EU_RETAIL_SUPPORT  AP_SEO  AP_ADVERTISING  \
# 0            9000               4000    4000            8000
# 1           12100               4375    5150           12350
# 2           16050               4750    6350           16300
# 3           20250               4325    7775           20600
# 4           20550               3575    6850           19850
# 5           25250               3250    8225           22750
#
#    AP_RETAIL_SUPPORT  LA_SEO  LA_ADVERTISING  LA_RETAIL_SUPPORT
# ...

# %% [markdown]
# ## Find The Slope Intercept for each segment
# Let's start off with some simple Linear Regressions using Least Squares

# %%
# x will is Year and will be used in all the models
x = np.array(df['YEAR'])

# each y will be for the segment we're looking at
y_na_seo = np.array(df['NA_SEO'])
y_na_advertising = np.array(df['NA_ADVERTISING'])
y_na_retailsup = np.array(df['NA_RETAIL_SUPPORT'])
y_eu_seo = np.array(df['EU_SEO'])
y_eu_advertising = np.array(df['EU_ADVERTISING'])
y_eu_retailsup = np.array(df['EU_RETAIL_SUPPORT'])
y_ap_seo = np.array(df['AP_SEO'])
y_ap_advertising = np.array(df['AP_ADVERTISING'])
y_ap_retailsup = np.array(df['AP_RETAIL_SUPPORT'])
y_la_seo = np.array(df['LA_SEO'])
y_la_advertising = np.array(df['LA_ADVERTISING'])
y_la_retailsup = np.array(df['LA_RETAIL_SUPPORT'])

#Fitting a linear model to the above data

#NORTH AMERICA
na_seo_slope, na_seo_intercept = np.polyfit(x,y_na_seo,1)
na_advertising_slope, na_advertising_intercept = np.polyfit(x,y_na_advertising,1)
na_retailsup_slope, na_retailsup_intercept = np.polyfit(x,y_na_retailsup,1)

#EUROPE AFRICA
eu_seo_slope, eu_seo_intercept = np.polyfit(x,y_eu_seo,1)
eu_advertising_slope, eu_advertising_intercept = np.polyfit(x,y_eu_advertising,1)
eu_retailsup_slope, eu_retailsup_intercept = np.polyfit(x,y_eu_retailsup,1)

#ASIA PACIFIC
ap_seo_slope, ap_seo_intercept = np.polyfit(x,y_ap_seo,1)
ap_advertising_slope, ap_advertising_intercept = np.polyfit(x,y_ap_advertising,1)
ap_retailsup_slope, ap_retailsup_intercept = np.polyfit(x,y_ap_retailsup,1)

#LATIN AMERICA
la_seo_slope, la_seo_intercept = np.polyfit(x,y_la_seo,1)
la_advertising_slope, la_advertising_intercept = np.polyfit(x,y_la_advertising,1)
la_retailsup_slope, la_retailsup_intercept = np.polyfit(x,y_la_retailsup,1)

#NORTH AMERICA printed as y=mx+b 
print('NA SEO = '+ str(na_seo_slope) + 'x + ' + str(na_seo_intercept))
print('NA Advertising = '+ str(na_advertising_slope) + 'x + ' + str(na_advertising_intercept))
print('NA Retailer Support = '+ str(na_retailsup_slope) + 'x + ' + str(na_retailsup_intercept))

#EUROPE AFRICA printed as y=mx+b 
print('EU SEO = '+ str(eu_seo_slope) + 'x + ' + str(eu_seo_intercept))
print('EU Advertising = '+ str(eu_advertising_slope) + 'x + ' + str(eu_advertising_intercept))
print('EU Retailer Support = '+ str(eu_retailsup_slope) + 'x + ' + str(eu_retailsup_intercept))

#ASIA PACIFIC printed as y=mx+b 
print('AP SEO = '+ str(ap_seo_slope) + 'x + ' + str(ap_seo_intercept))
print('AP Advertising = '+ str(ap_advertising_slope) + 'x + ' + str(ap_advertising_intercept))
print('AP Retailer Support = '+ str(ap_retailsup_slope) + 'x + ' + str(ap_retailsup_intercept))

#LATIN AMERICA printed as y=mx+b 
print('LA SEO = '+ str(la_seo_slope) + 'x + ' + str(la_seo_intercept))
print('LA Advertising = '+ str(la_advertising_slope) + 'x + ' + str(la_advertising_intercept))
print('LA Retailer Support = '+ str(la_retailsup_slope) + 'x + ' + str(la_retailsup_intercept))
# Out:
# NA SEO = 832.8571428571427x + -3277.380952380946
# NA Advertising = 2164.285714285714x + -10361.904761904749
# NA Retailer Support = -184.2857142857138x + 6361.904761904755
# EU SEO = 976.428571428571x + -4734.523809523796
# EU Advertising = 3165.714285714283x + -22371.42857142852
# EU Retailer Support = -187.85714285714243x + 6394.047619047613
# AP SEO = 789.9999999999998x + -3483.3333333333285
# AP Advertising = 2872.8571428571418x + -19269.04761904759
# AP Retailer Support = 54.285714285714455x + 2563.0952380952363
# LA SEO = 1413.5714285714268x + -10973.809523809497
# LA Advertising = 3685.7142857142835x + -29221.428571428518
# LA Retailer Support = 333.57142857142844x + -282.1428571428529

# %% [markdown]
# ### North America SEO

# %%
#plot hypothetical slope and intercept from above data
x_theor = np.array([10,predictionYear]) #for Year 10 through Prediction Year
y_theor = na_seo_slope * x_theor + na_seo_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_seo_slope * predictionYear + na_seo_intercept))

#plot the anscombe data and theoretical line
_ = plt.plot(x,y_na_seo,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)

#label the axes
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA SEO')
plt.show()
# Out:
# Year 16 predicted: 10048.333333333336

# %% [markdown]
# ### North America Brand Advertising

# %%
x_theor = np.array([10,predictionYear])
y_theor = na_advertising_slope * x_theor + na_advertising_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_advertising_slope * predictionYear + na_advertising_intercept))
_ = plt.plot(x,y_na_advertising,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA Advertising')
plt.show()
# Out:
# Year 16 predicted: 24266.66666666668

# %% [markdown]
# ### North America Retailer Support

# %%
x_theor = np.array([10,predictionYear])
y_theor = na_retailsup_slope * x_theor + na_retailsup_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_retailsup_slope * predictionYear + na_retailsup_intercept))
_ = plt.plot(x,y_na_retailsup,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA Retailer Support')
plt.show()
# Out:
# Year 16 predicted: 3413.3333333333344

# %% [markdown]
# ### Europe Africa SEO

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_seo_slope * x_theor + eu_seo_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_seo_slope * predictionYear + eu_seo_intercept))
_ = plt.plot(x,y_eu_seo,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU SEO')
plt.show()
# Out:
# Year 16 predicted: 10888.33333333334

# %% [markdown]
# ### Europe Africa Brand Advertising

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_advertising_slope * x_theor + eu_advertising_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_advertising_slope * predictionYear + eu_advertising_intercept))
_ = plt.plot(x,y_eu_advertising,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU Advertising')
plt.show()
# Out:
# Year 16 predicted: 28280.000000000007

# %% [markdown]
# ### Europe Africa Retailer Support

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_retailsup_slope * x_theor + eu_retailsup_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_retailsup_slope * predictionYear + eu_retailsup_intercept))
_ = plt.plot(x,y_eu_retailsup,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU Retailer Support')
plt.show()
# Out:
# Year 16 predicted: 3388.333333333334

# %% [markdown]
# ### Asia Pacific SEO

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_seo_slope * x_theor + ap_seo_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_seo_slope * predictionYear + ap_seo_intercept))
_ = plt.plot(x,y_ap_seo,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP SEO')
plt.show()
# Out:
# Year 16 predicted: 9156.666666666668

# %% [markdown]
# ### Asia Pacific Brand Advertising

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_advertising_slope * x_theor + ap_advertising_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_advertising_slope * predictionYear + ap_advertising_intercept))
_ = plt.plot(x,y_ap_advertising,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP Advertising')
plt.show()
# Out:
# Year 16 predicted: 26696.66666666668

# %% [markdown]
# ### Asia Pacific Retailer Support

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_retailsup_slope * x_theor + ap_retailsup_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_retailsup_slope * predictionYear + ap_retailsup_intercept))
_ = plt.plot(x,y_ap_retailsup,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP Retailer Support')
plt.show()
# Out:
# Year 16 predicted: 3431.6666666666674

# %% [markdown]
# ### Latin America SEO

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_seo_slope * x_theor + la_seo_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_seo_slope * predictionYear + la_seo_intercept))
_ = plt.plot(x,y_la_seo,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA SEO')
plt.show()
# Out:
# Year 16 predicted: 11643.333333333332

# %% [markdown]
# ### Latin America Brand Advertising

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_advertising_slope * x_theor + la_advertising_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_advertising_slope * predictionYear + la_advertising_intercept))
_ = plt.plot(x,y_la_advertising,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA Advertising')
plt.show()
# Out:
# Year 16 predicted: 29750.00000000002

# %% [markdown]
# ### Latin America Retailer Support

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_retailsup_slope * x_theor + la_retailsup_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_retailsup_slope * predictionYear + la_retailsup_intercept))
_ = plt.plot(x,y_la_retailsup,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA Retailer Support')
plt.show()
# Out:
# Year 16 predicted: 5055.000000000002
