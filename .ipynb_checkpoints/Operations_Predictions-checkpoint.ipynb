# %% [markdown]
# # Predicting Operations and Rebates: S/Q, Models, Delivery Time, Rebate Offers, Delivery Time

# %%
#let's grab a few packages for stats
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Let's set some variables that we'll change each round
#Change this year to the year being predicted (i.e. if you're predicting year 16, enter '16')
predictionYear = 16 

#Load the dataset from our bsg_prices_actual - Sheet1.csv
df = pd.read_csv('bsg_operations_actual - Sheet1.csv')
df
# Out:
#    ID  YEAR  NA_SQ  NA_MODELS  NA_REBATE  NA_DELIVERY_TIME  NA_SHIPPING  \
# 0   0    10    4.0        200        5.0               3.0            0
# 1   1    11    6.3        258        5.3               2.2            1
# 2   2    12    6.8        330        4.9               2.0            2
# 3   3    13    6.5        273        4.8               2.0            2
# 4   4    14    6.3        363        4.4               1.7            2
# 5   5    15    6.4        381        3.9               2.0            2
#
#    EU_SQ  EU_MODELS  EU_REBATE     ...       AP_SQ  AP_MODELS  AP_REBATE  \
# 0    4.0        200        5.0     ...         4.0        200        5.0
# 1    6.4        240        5.1     ...         6.1        234        5.1
# 2    6.9        317        4.8     ...         6.6        334        4.6
# 3    7.0        252        4.5     ...         6.1        365        4.0
# 4    6.1        322        4.6     ...         5.1        395        4.3
# ...

# %% [markdown]
# ## Find The Slope Intercept for each segment
# Let's start off with some simple Linear Regressions using Least Squares

# %%
# x will is Year and will be used in all the models
x = np.array(df['YEAR'])

# each y will be for the segment we're looking at
y_na_sq = np.array(df['NA_SQ'])
y_na_models = np.array(df['NA_MODELS'])
y_na_rebate = np.array(df['NA_REBATE'])
y_na_delivery = np.array(df['NA_DELIVERY_TIME'])
y_na_shipping = np.array(df['NA_SHIPPING'])
y_eu_sq = np.array(df['EU_SQ'])
y_eu_models = np.array(df['EU_MODELS'])
y_eu_rebate = np.array(df['EU_REBATE'])
y_eu_delivery = np.array(df['EU_DELIVERY_TIME'])
y_eu_shipping = np.array(df['EU_SHIPPING'])
y_ap_sq = np.array(df['AP_SQ'])
y_ap_models = np.array(df['AP_MODELS'])
y_ap_rebate = np.array(df['AP_REBATE'])
y_ap_delivery = np.array(df['AP_DELIVERY_TIME'])
y_ap_shipping = np.array(df['AP_SHIPPING'])
y_la_sq = np.array(df['LA_SQ'])
y_la_models = np.array(df['LA_MODELS'])
y_la_rebate = np.array(df['LA_REBATE'])
y_la_delivery = np.array(df['LA_DELIVERY_TIME'])
y_la_shipping = np.array(df['LA_SHIPPING'])

#Fitting a linear model to the above data

#NORTH AMERICA
na_sq_slope, na_sq_intercept = np.polyfit(x,y_na_sq,1)
na_models_slope, na_models_intercept = np.polyfit(x,y_na_models,1)
na_rebate_slope, na_rebate_intercept = np.polyfit(x,y_na_rebate,1)
na_delivery_slope, na_delivery_intercept = np.polyfit(x,y_na_delivery,1)
na_shipping_slope, na_shipping_intercept = np.polyfit(x,y_na_shipping,1)

#EUROPE AFRICA
eu_sq_slope, eu_sq_intercept = np.polyfit(x,y_eu_sq,1)
eu_models_slope, eu_models_intercept = np.polyfit(x,y_eu_models,1)
eu_rebate_slope, eu_rebate_intercept = np.polyfit(x,y_eu_rebate,1)
eu_delivery_slope, eu_delivery_intercept = np.polyfit(x,y_eu_delivery,1)
eu_shipping_slope, eu_shipping_intercept = np.polyfit(x,y_eu_shipping,1)

#ASIA PACIFIC
ap_sq_slope, ap_sq_intercept = np.polyfit(x,y_ap_sq,1)
ap_models_slope, ap_models_intercept = np.polyfit(x,y_ap_models,1)
ap_rebate_slope, ap_rebate_intercept = np.polyfit(x,y_ap_rebate,1)
ap_delivery_slope, ap_delivery_intercept = np.polyfit(x,y_ap_delivery,1)
ap_shipping_slope, ap_shipping_intercept = np.polyfit(x,y_ap_shipping,1)

#LATIN AMERICA
la_sq_slope, la_sq_intercept = np.polyfit(x,y_la_sq,1)
la_models_slope, la_models_intercept = np.polyfit(x,y_la_models,1)
la_rebate_slope, la_rebate_intercept = np.polyfit(x,y_la_rebate,1)
la_delivery_slope, la_delivery_intercept = np.polyfit(x,y_la_delivery,1)
la_shipping_slope, la_shipping_intercept = np.polyfit(x,y_la_shipping,1)

#NORTH AMERICA printed as y=mx+b 
print('NA SQ = '+ str(na_sq_slope) + 'x + ' + str(na_sq_intercept))
print('NA Models = '+ str(na_models_slope) + 'x + ' + str(na_models_intercept))
print('NA Rebate = '+ str(na_rebate_slope) + 'x + ' + str(na_rebate_intercept))
print('NA Delivery = '+ str(na_delivery_slope) + 'x + ' + str(na_delivery_intercept))
print('NA Shipping = '+ str(na_shipping_slope) + 'x + ' + str(na_shipping_intercept))

#EUROPE AFRICA printed as y=mx+b 
print('EU SQ = '+ str(eu_sq_slope) + 'x + ' + str(eu_sq_intercept))
print('EU Models = '+ str(eu_models_slope) + 'x + ' + str(eu_models_intercept))
print('EU Rebate = '+ str(eu_rebate_slope) + 'x + ' + str(eu_rebate_intercept))
print('EU Delivery = '+ str(eu_delivery_slope) + 'x + ' + str(eu_delivery_intercept))
print('EU Shipping = '+ str(eu_shipping_slope) + 'x + ' + str(eu_shipping_intercept))

#ASIA PACIFIC printed as y=mx+b 
print('AP SQ = '+ str(ap_sq_slope) + 'x + ' + str(ap_sq_intercept))
print('AP Models = '+ str(ap_models_slope) + 'x + ' + str(ap_models_intercept))
print('AP Rebate = '+ str(ap_rebate_slope) + 'x + ' + str(ap_rebate_intercept))
print('AP Delivery = '+ str(ap_delivery_slope) + 'x + ' + str(ap_delivery_intercept))
print('AP Shipping = '+ str(ap_shipping_slope) + 'x + ' + str(ap_shipping_intercept))

#LATIN AMERICA printed as y=mx+b 
print('LA SQ = '+ str(la_sq_slope) + 'x + ' + str(la_sq_intercept))
print('LA Models = '+ str(la_models_slope) + 'x + ' + str(la_models_intercept))
print('LA Rebate = '+ str(la_rebate_slope) + 'x + ' + str(la_rebate_intercept))
print('LA Delivery = '+ str(la_delivery_slope) + 'x + ' + str(la_delivery_intercept))
print('LA Shipping = '+ str(la_shipping_slope) + 'x + ' + str(la_shipping_intercept))
# Out:
# NA SQ = 0.3342857142857147x + 1.871428571428567
# NA Models = 33.22857142857143x + -114.52380952380928
# NA Rebate = -0.23714285714285677x + 7.680952380952375
# NA Delivery = -0.18571428571428578x + 4.471428571428572
# NA Shipping = 0.37142857142857144x + -3.142857142857141
# EU SQ = 0.3342857142857146x + 1.9714285714285702
# EU Models = 24.028571428571414x + -23.19047619047585
# EU Rebate = -0.13714285714285696x + 6.447619047619046
# EU Delivery = -0.22571428571428556x + 5.0714285714285685
# EU Shipping = 0.37142857142857144x + -3.142857142857141
# AP SQ = 0.21428571428571477x + 3.0047619047618994
# AP Models = 39.828571428571415x + -180.52380952380923
# AP Rebate = -0.1285714285714283x + 6.22380952380952
# AP Delivery = -0.18857142857142858x + 4.523809523809523
# AP Shipping = 0.37142857142857144x + -3.142857142857141
# LA SQ = 0.4514285714285716x + 0.6238095238095261
# LA Models = 28.05714285714285x + -79.71428571428548
# LA Rebate = -0.05714285714285703x + 5.514285714285713
# ...

# %% [markdown]
# ### North America S/Q

# %%
#plot hypothetical slope and intercept from above data
x_theor = np.array([10,predictionYear]) #for Year 10 through Prediction Year
y_theor = na_sq_slope * x_theor + na_sq_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_sq_slope * predictionYear + na_sq_intercept))

#plot the anscombe data and theoretical line
_ = plt.plot(x,y_na_sq,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)

#label the axes
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA S/Q')
plt.show()
# Out:
# Year 16 predicted: 7.220000000000002

# %% [markdown]
# ### North America Model Availability

# %%
x_theor = np.array([10,predictionYear])
y_theor = na_models_slope * x_theor + na_models_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_models_slope * predictionYear + na_models_intercept))
_ = plt.plot(x,y_na_models,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA Models')
plt.show()
# Out:
# Year 16 predicted: 417.13333333333355

# %% [markdown]
# ### North America Manufacturer Rebates

# %%
x_theor = np.array([10,predictionYear])
y_theor = na_rebate_slope * x_theor + na_rebate_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_rebate_slope * predictionYear + na_rebate_intercept))
_ = plt.plot(x,y_na_rebate,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA Rebates')
plt.show()
# Out:
# Year 16 predicted: 3.8866666666666667

# %% [markdown]
# ### North America Delivery

# %%
x_theor = np.array([10,predictionYear])
y_theor = na_delivery_slope * x_theor + na_delivery_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_delivery_slope * predictionYear + na_delivery_intercept))
_ = plt.plot(x,y_na_delivery,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA Delivery Time')
plt.show()
# Out:
# Year 16 predicted: 1.5

# %% [markdown]
# ### North America Shipping

# %%
x_theor = np.array([10,predictionYear])
y_theor = na_shipping_slope * x_theor + na_shipping_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(na_shipping_slope * predictionYear + na_shipping_intercept))
_ = plt.plot(x,y_na_shipping,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('NA Internet Shipping')
plt.show()
# Out:
# Year 16 predicted: 2.800000000000002

# %% [markdown]
# ### Europe Africa S/Q

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_sq_slope * x_theor + eu_sq_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_sq_slope * predictionYear + eu_sq_intercept))
_ = plt.plot(x,y_eu_sq,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU S/Q')
plt.show()
# Out:
# Year 16 predicted: 7.320000000000004

# %% [markdown]
# ### Europe Africa Model Availability

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_models_slope * x_theor + eu_models_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_models_slope * predictionYear + eu_models_intercept))
_ = plt.plot(x,y_eu_models,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU Models')
plt.show()
# Out:
# Year 16 predicted: 361.26666666666677

# %% [markdown]
# ### Europe Africa Manufacturer Rebate

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_rebate_slope * x_theor + eu_rebate_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_rebate_slope * predictionYear + eu_rebate_intercept))
_ = plt.plot(x,y_eu_rebate,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU Rebates')
plt.show()
# Out:
# Year 16 predicted: 4.253333333333335

# %% [markdown]
# ### Europe Africa Delivery

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_delivery_slope * x_theor + eu_delivery_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_delivery_slope * predictionYear + eu_delivery_intercept))
_ = plt.plot(x,y_eu_delivery,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU Delivery Time')
plt.show()
# Out:
# Year 16 predicted: 1.4599999999999995

# %% [markdown]
# ### Europe Africa Shipping

# %%
x_theor = np.array([10,predictionYear])
y_theor = eu_shipping_slope * x_theor + eu_shipping_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(eu_shipping_slope * predictionYear + eu_shipping_intercept))
_ = plt.plot(x,y_eu_shipping,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('EU Internet Shipping')
plt.show()
# Out:
# Year 16 predicted: 2.800000000000002

# %% [markdown]
# ### Asia Pacific S/Q

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_sq_slope * x_theor + ap_sq_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_sq_slope * predictionYear + ap_sq_intercept))
_ = plt.plot(x,y_ap_sq,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP S/Q')
plt.show()
# Out:
# Year 16 predicted: 6.433333333333335

# %% [markdown]
# ### Asia Pacific Model Availability

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_models_slope * x_theor + ap_models_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_models_slope * predictionYear + ap_models_intercept))
_ = plt.plot(x,y_ap_models,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP Models')
plt.show()
# Out:
# Year 16 predicted: 456.7333333333334

# %% [markdown]
# ### Asia Pacific Manufacturer Rebate

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_rebate_slope * x_theor + ap_rebate_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_rebate_slope * predictionYear + ap_rebate_intercept))
_ = plt.plot(x,y_ap_rebate,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP Rebates')
plt.show()
# Out:
# Year 16 predicted: 4.166666666666668

# %% [markdown]
# ### Asia Pacific Delivery

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_delivery_slope * x_theor + ap_delivery_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_delivery_slope * predictionYear + ap_delivery_intercept))
_ = plt.plot(x,y_ap_delivery,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP Delivery Time')
plt.show()
# Out:
# Year 16 predicted: 1.5066666666666655

# %% [markdown]
# ### Asia Pacific Shipping

# %%
x_theor = np.array([10,predictionYear])
y_theor = ap_shipping_slope * x_theor + ap_shipping_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(ap_shipping_slope * predictionYear + ap_shipping_intercept))
_ = plt.plot(x,y_ap_shipping,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('AP Internet Shipping')
plt.show()
# Out:
# Year 16 predicted: 2.800000000000002

# %% [markdown]
# ### Latin America S/Q

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_sq_slope * x_theor + la_sq_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_sq_slope * predictionYear + la_sq_intercept))
_ = plt.plot(x,y_la_sq,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA S/Q')
plt.show()
# Out:
# Year 16 predicted: 7.846666666666672

# %% [markdown]
# ### Latin America Model Availability

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_models_slope * x_theor + la_models_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_models_slope * predictionYear + la_models_intercept))
_ = plt.plot(x,y_la_models,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA Models')
plt.show()
# Out:
# Year 16 predicted: 369.2000000000001

# %% [markdown]
# ### Latin America Manufacturer Rebate

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_rebate_slope * x_theor + la_rebate_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_rebate_slope * predictionYear + la_rebate_intercept))
_ = plt.plot(x,y_la_rebate,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA Rebates')
plt.show()
# Out:
# Year 16 predicted: 4.6000000000000005

# %% [markdown]
# ### Latin America Delivery

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_delivery_slope * x_theor + la_delivery_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_delivery_slope * predictionYear + la_delivery_intercept))
_ = plt.plot(x,y_la_delivery,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA Delivery Time')
plt.show()
# Out:
# Year 16 predicted: 1.3466666666666676

# %% [markdown]
# ### Latin America Shipping

# %%
x_theor = np.array([10,predictionYear])
y_theor = la_shipping_slope * x_theor + la_shipping_intercept
print('Year ' + str(predictionYear) +' predicted: ' + str(la_shipping_slope * predictionYear + la_shipping_intercept))
_ = plt.plot(x,y_la_shipping,marker='.', linestyle='none')
_ = plt.plot(x_theor,y_theor)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('LA Internet Shipping')
plt.show()
# Out:
# Year 16 predicted: 3.4666666666666694
